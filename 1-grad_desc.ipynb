# %%
from io import StringIO
import pandas as pd
import seaborn as sns
from scipy import stats 
import numpy as np

# %%
csvTextData = """
X	Y
1	4
-2	3
3	6
4.5	8
0	2
-4	-3
-1	-2
4	7
-1	2.5
"""

df = pd.read_csv(StringIO(csvTextData), sep='\t')
df = pd.ord

# %%
linreg = stats.linregress(df['X'].values, df['Y'].values)
y_reg = linreg.intercept + (linreg.slope * df['Y'].values)

sns.regplot(data=df, x='X', y='Y', line_kws={'color':'red'})
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
X = df['X'].values
Y = df['Y'].values

# random values
m = 0.3
b = 0.3

def f_pred(X, m, b):
    return m*X + b

# def gradient(x0, m, b):
# Out:
# array([-3.4 , -3.3 , -4.8 , -6.35, -1.7 ,  2.1 ,  2.  , -5.5 , -2.5 ])

# %%
# test
x = [1,2,3]

x.append(4)

y = x

x.append(5)
y.append(6)

print(x,y)
# Out:
# [1, 2, 3, 4, 5, 6] [1, 2, 3, 4, 5, 6]
